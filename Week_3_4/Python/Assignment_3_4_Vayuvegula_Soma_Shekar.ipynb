# %% [markdown]
# # Assignment_3_4_Vayuvegula_Soma_Shekar_Python

# %%
#import libraries
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
#Read excel
df_world = pd.read_excel("world-population.xlsm")

# %%
df_world.head()
# Out:
#    Year  Population
# 0  1960  3028654024
# 1  1961  3068356747
# 2  1962  3121963107
# 3  1963  3187471383
# 4  1964  3253112403

# %%
#Line Chart
df_world.plot(x='Year',y='Population',kind='line',color='blue')
plt.legend(["World Population"])
plt.xlabel("Year",size=15)
plt.ylabel("Population (in Billions)",size=15)
plt.title("World Population - Line Chart")
plt.show()
plt.close()

# %%
#Step Chart
plt.figure()
year_list=df_world['Year'].to_list()
pop_list=df_world['Population'].to_list()
plt.plot(year_list,pop_list,drawstyle='steps',linestyle='-',alpha=1,color='grey')
plt.legend(["World Population"])
plt.xlabel("Year",size=15)
plt.ylabel("Population (in Billions)",size=15)
plt.title("World Population - Step Chart")
plt.show()
plt.close()
